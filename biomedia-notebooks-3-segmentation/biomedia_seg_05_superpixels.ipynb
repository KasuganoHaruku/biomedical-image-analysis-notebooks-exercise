# %% [markdown]
# <div class="alert alert-block alert-info">
# Visit the <a href="https://github.com/engs1258/biomedical-image-analysis-notebooks/wiki">wiki</a> pages to find some additional documentation and instructions on how view an interactive verson of these notebooks using binder.</div>
#
# ---

# %%
import math
import numpy as np
import matplotlib.pyplot as plt


from skimage import io
from skimage.segmentation import slic
from skimage.segmentation import mark_boundaries

# %matplotlib inline
# Out:
# C:\Users\haruk\anaconda3\Lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated
#   "class": algorithms.Blowfish,

# %% [markdown]
# ## Partition the image into superpixels

# %%
image = io.imread("../images/tma.jpg")
rows, cols, depth = image.shape
print(rows)
print(cols)
print(depth)
# Out:
# 600
# 600
# 3

# %%
fig, ax = plt.subplots(figsize=(8, 8))
plt.imshow(image)

# %%
segments_slic_0 = slic(image, n_segments=200, compactness=5, sigma=.5)
segments_slic_1 = slic(image, n_segments=200, compactness=30, sigma=.5)
segments_slic_2 = slic(image, n_segments=200, compactness=400, sigma=.5)
print(np.amax(segments_slic_0))
print(np.amax(segments_slic_1))
print(np.amax(segments_slic_2))
# Out:
# 62
# 182
# 196

# %% [markdown]
# Notice what happens when the compactness of the superpixels is slow (left image).

# %%
fig, ax = plt.subplots(figsize=(16, 16))
plt.subplot(1,3,1).set_axis_off()
plt.imshow(mark_boundaries(image, segments_slic_0))
plt.subplot(1,3,2).set_axis_off()
plt.imshow(mark_boundaries(image, segments_slic_1))
plt.subplot(1,3,3).set_axis_off()
plt.imshow(mark_boundaries(image, segments_slic_2))
plt.show()
# Out:
# C:\Users\haruk\AppData\Local\Temp\ipykernel_12304\2804726198.py:2: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(1,3,1).set_axis_off()
