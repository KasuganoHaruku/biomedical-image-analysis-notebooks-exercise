# %% [markdown]
# <div class="alert alert-block alert-info">
# Visit the <a href="https://github.com/engs1258/biomedical-image-analysis-notebooks/wiki">wiki</a> pages to find some additional documentation and instructions on how view an interactive verson of these notebooks using binder.</div>
#
# ---

# %%
# %matplotlib inline

# %%
import math
import numpy as np
import matplotlib.pyplot as plt


from skimage import io
from skimage import filters

# %matplotlib inline
# Out:
# C:\Users\haruk\anaconda3\Lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated
#   "class": algorithms.Blowfish,

# %% [markdown]
# ## Global Threshold - Example 1

# %%
image = io.imread("../images/nuclei-dapi.tif")

# %%
threshold = 54
print(threshold) 
binary = ~(image <= threshold)
# Out:
# 54

# %%
fig, ax = plt.subplots(figsize=(10, 10))
plt.subplot(1,2,1)
plt.imshow(image, cmap='gray')
plt.subplot(1,2, 2)
plt.imshow(binary, cmap='gray')
plt.show()
# Out:
# C:\Users\haruk\AppData\Local\Temp\ipykernel_23152\2547512363.py:2: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(1,2,1)

# %% [markdown]
# ## Global Otsu Threshold - Example 2

# %%
image = io.imread("../images/Lyuba-CT_350.tif")

# %%
threshold = 55
print(threshold) 
binary = ~(image <= threshold)
# Out:
# 55

# %%
fig, ax = plt.subplots(figsize=(10, 10))
plt.subplot(1,2,1)
plt.imshow(image, cmap='gray')
plt.subplot(1,2, 2)
plt.imshow(binary, cmap='gray')
plt.show()
# Out:
# C:\Users\haruk\AppData\Local\Temp\ipykernel_23152\2547512363.py:2: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(1,2,1)
